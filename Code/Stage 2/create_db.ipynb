# %%
dataname="tissue"

patch_size=256 #size of the tiles to extract and save in the database, must be >= to training size
stride_size=256 #distance to skip between patches, 1 indicated pixel wise extraction, patch_size would result in non-overlapping tiles
mirror_pad_size=128 # number of pixels to pad *after* resize to image with by mirroring (edge's of patches tend not to be analyzed well, so padding allows them to appear more centered in the patch)
test_set_size=.1 # what percentage of the dataset should be used as a held out validation/testing set
resize_scale=1 #resize input images
class_names=["negative", "positive"]#what classes we expect to have in the data, here we have only 2 classes but we could add additional classes

#-----Note---
#One should likely make sure that  (nrow+mirror_pad_size) mod patch_size == 0, where nrow is the number of rows after resizing
#so that no pixels are lost (any remainer is ignored)

# %%
import torch
import tables

import os,sys
import glob

import PIL
import numpy as np

import cv2
import matplotlib.pyplot as plt

from sklearn import model_selection
from patchify import patchify
import random


seed = random.randrange(sys.maxsize) #get a random seed so that we can reproducibly do the cross validation setup
random.seed(seed) # set the seed
print(f"random seed (note down for reproducibility): {seed}")
# Out:
# random seed (note down for reproducibility): 6968726797688606138

# %%
img_dtype = tables.UInt8Atom()  # dtype in which the images will be saved, this indicates that images will be saved as unsigned int 8 bit, i.e., [0,255]
filenameAtom = tables.StringAtom(itemsize=255) #create an atom to store the filename of the image, just incase we need it later,

# %%
files=glob.glob('./data/**/*.jpg') # create a list of the files, in this case we're only interested in files which have masks so we can use supervised learning
sp = model_selection.ShuffleSplit(n_splits=1,test_size=test_set_size) # define split parameters

#create training and validation stages and split the files appropriately between them
phases={}
phases["train"],phases["val"]=next(iter(sp.split(files))) # with n_splits=1 sp.split will generate only 1 iteration

# %%
#--subset for rapid testing
phases["train"]=phases["train"][0:100]
phases["val"]=phases["val"][0:20]

# %%
storage={} #holder for future pytables

block_shape=np.array((patch_size,patch_size,3)) #block shape specifies what we'll be saving into the pytable array, here we assume that masks are 1d and images are 3d

filters=tables.Filters(complevel=6, complib='zlib') #we can also specify filters, such as compression, to improve storage speed


for phase in phases.keys(): #now for each of the phases, we'll loop through the files
    print(phase)
    
    totals=np.zeros(len(class_names)) # we can to keep counts of all the classes in for in particular training, since we 
    
    hdf5_file = tables.open_file(f"./{dataname}_{phase}.pytable", mode='w') #open the respective pytable
    storage["filenames"] = hdf5_file.create_earray(hdf5_file.root, 'filenames', filenameAtom, (0,)) #create the array for storage
    
    storage["imgs"]= hdf5_file.create_earray(hdf5_file.root, "imgs", img_dtype,  
                                              shape=np.append([0],block_shape), 
                                              chunkshape=np.append([1],block_shape),
                                              filters=filters)
    storage["labels"]= hdf5_file.create_earray(hdf5_file.root, "labels", img_dtype,  
                                              shape=[0], 
                                              chunkshape=[1],
                                              filters=filters)

    
    for filei in phases[phase]: #now for each of the files
        fname=files[filei] 
        print(fname)
        
        classid=[idx for idx in range(len(class_names)) if class_names[idx] in fname][0]
        totals[classid]+=1

        io=cv2.cvtColor(cv2.imread(fname),cv2.COLOR_BGR2RGB)
        interp_method=PIL.Image.BICUBIC

        io = cv2.resize(io,(0,0),fx=resize_scale,fy=resize_scale, interpolation=interp_method) #resize it as specified above
        io = np.pad(io, [(mirror_pad_size, mirror_pad_size), (mirror_pad_size, mirror_pad_size), (0, 0)], mode="reflect")

        #convert input image into overlapping tiles, size is ntiler x ntilec x 1 x patch_size x patch_size x3
        io_arr_out=patchify(io, (patch_size, patch_size, 3), step=stride_size)

        #resize it into a ntile x patch_size x patch_size x 3
        io_arr_out=io_arr_out.reshape(-1,patch_size,patch_size,3)

        storage["imgs"].append(io_arr_out)
        storage["labels"].append([classid for x in range(io_arr_out.shape[0])]) #add the filename to the storage array
        storage["filenames"].append([fname for x in range(io_arr_out.shape[0])]) #add the filename to the storage array
        
    #lastly, we should store the number of each class instances
    classsizes=hdf5_file.create_carray(hdf5_file.root, 'classsizes', tables.Atom.from_dtype(totals.dtype), totals.shape)
    classsizes[:]=totals
    hdf5_file.close()
# Out:
# train
# ./data\positive\21 (11).jpg
# ./data\positive\16 (43).jpg
# ./data\positive\29 (22).jpg
# ./data\negative\10 (11).jpg
# ./data\positive\16 (86).jpg
# ./data\positive\20 (39).jpg
# ./data\negative\41 (24).jpg
# ./data\positive\8 (24).jpg
# ./data\positive\22 (21).jpg
# ./data\positive\8 (12).jpg
# ./data\negative\16 (31).jpg
# ./data\positive\16 (44).jpg
# ./data\positive\11 (13).jpg
# ./data\positive\21 (2).jpg
# ./data\negative\38 (1).jpg
# ./data\positive\29 (16).jpg
# ./data\positive\20 (9).jpg
# ./data\negative\29 (11).jpg
# ./data\positive\20 (4).jpg
# ./data\negative\46 (1).jpg
# ./data\positive\6 (6).jpg
# ./data\positive\29 (28).jpg
# ./data\positive\4 (7).jpg
# ./data\positive\29 (26).jpg
# ./data\negative\52 (3).jpg
# ./data\negative\39 (4).jpg
# ./data\negative\41 (19).jpg
# ./data\negative\43 (4).jpg
# ./data\negative\24 (1).jpg
# ./data\positive\25 (8).jpg
# ./data\positive\15 (12).jpg
# ./data\positive\2 (8).jpg
# ./data\negative\54 (4).jpg
# ./data\positive\2 (21).jpg
# ./data\positive\33 (1).jpg
# ./data\positive\22 (24).jpg
# ./data\negative\36 (6).jpg
# ./data\positive\16 (92).jpg
# ./data\negative\58 (7).jpg
# ./data\positive\1 (19).jpg
# ./data\positive\20 (32).jpg
# ./data\positive\9 (23).jpg
# ./data\positive\11 (23).jpg
# ./data\positive\3 (12).jpg
# ./data\positive\22 (1).jpg
# ./data\positive\5 (32).jpg
# ./data\positive\18 (30).jpg
# ./data\negative\16 (8).jpg
# ./data\positive\22 (4).jpg
# ./data\positive\26 (3).jpg
# ./data\negative\36 (16).jpg
# ./data\positive\16 (1).jpg
# ./data\positive\14 (48).jpg
# ./data\positive\1 (9).jpg
# ./data\positive\29 (24).jpg
# ./data\positive\1 (14).jpg
# ./data\negative\57 (12).jpg
# ./data\negative\36 (3).jpg
# ./data\positive\14 (18).jpg
# ./data\negative\41 (23).jpg
# ./data\positive\22 (9).jpg
# ./data\positive\13 (13).jpg
# ./data\positive\13 (39).jpg
# ./data\negative\57 (5).jpg
# ./data\positive\9 (13).jpg
# ./data\negative\55 (12).jpg
# ./data\positive\14 (57).jpg
# ./data\negative\43 (11).jpg
# ./data\positive\16 (21).jpg
# ./data\negative\55 (8).jpg
# ./data\negative\54 (8).jpg
# ./data\positive\5 (15).jpg
# ./data\negative\10 (12).jpg
# ./data\negative\46 (8).jpg
# ./data\positive\9 (20).jpg
# ./data\positive\6 (18).jpg
# ./data\negative\46 (3).jpg
# ./data\negative\57 (23).jpg
# ./data\positive\29 (13).jpg
# ./data\positive\9 (5).jpg
# ./data\positive\2 (17).jpg
# ./data\positive\5 (27).jpg
# ./data\positive\7 (17).jpg
# ./data\negative\46 (21).jpg
# ./data\positive\5 (2).jpg
# ./data\negative\14 (16).jpg
# ./data\negative\18 (16).jpg
# ./data\negative\48 (17).jpg
# ./data\negative\14 (56).jpg
# ./data\negative\41 (14).jpg
# ./data\positive\31 (10).jpg
# ./data\positive\24 (9).jpg
# ./data\negative\53 (4).jpg
# ./data\negative\24 (3).jpg
# ./data\negative\43 (7).jpg
# ./data\negative\49 (3).jpg
# ./data\positive\18 (34).jpg
# ./data\negative\39 (1).jpg
# ./data\positive\2 (16).jpg
# ./data\positive\2 (3).jpg
# ./data\positive\28 (11).jpg
# ./data\positive\29 (37).jpg
# ./data\negative\41 (25).jpg
# ./data\negative\21 (14).jpg
# ./data\negative\19 (13).jpg
# ./data\negative\41 (34).jpg
# ./data\negative\46 (16).jpg
# ./data\negative\42 (4).jpg
# ./data\positive\30 (17).jpg
# ./data\positive\7 (32).jpg
# ./data\positive\18 (41).jpg
# ./data\positive\16 (83).jpg
# ./data\positive\7 (7).jpg
# ./data\negative\24 (15).jpg
# ./data\positive\9 (2).jpg
# ./data\negative\56 (9).jpg
# ./data\positive\18 (46).jpg
# ./data\positive\14 (7).jpg
# ./data\positive\7 (6).jpg
# ./data\positive\16 (53).jpg
# ./data\negative\46 (15).jpg
# ./data\negative\14 (14).jpg
# ./data\negative\53 (1).jpg
# ./data\positive\19 (15).jpg
# ./data\negative\14 (28).jpg
# ./data\negative\48 (20).jpg
# ./data\positive\26 (5).jpg
# ./data\negative\18 (9).jpg
# ./data\positive\28 (4).jpg
# ./data\negative\41 (6).jpg
# ./data\positive\9 (3).jpg
# ./data\negative\41 (11).jpg
# ./data\negative\7 (42).jpg
# ./data\positive\10 (35).jpg
# ./data\positive\22 (16).jpg
# ./data\positive\29 (12).jpg
# ./data\negative\55 (2).jpg
# ./data\negative\31 (7).jpg
# ./data\negative\42 (6).jpg
# ./data\positive\14 (60).jpg
# ./data\negative\31 (5).jpg
# ./data\positive\11 (21).jpg
# ./data\positive\6 (9).jpg
# ./data\positive\29 (18).jpg
# ./data\positive\19 (16).jpg
# ./data\positive\30 (6).jpg
# ./data\positive\22 (3).jpg
# ./data\positive\33 (7).jpg
# ./data\positive\20 (3).jpg
# ./data\negative\48 (6).jpg
# ./data\positive\31 (4).jpg
# ./data\positive\20 (25).jpg
# ./data\positive\22 (14).jpg
# ./data\positive\16 (26).jpg
# ./data\positive\9 (22).jpg
# ./data\positive\7 (5).jpg
# ./data\positive\14 (50).jpg
# ./data\positive\13 (21).jpg
# ./data\positive\18 (39).jpg
# ./data\positive\20 (34).jpg
# ./data\positive\16 (41).jpg
# ./data\negative\7 (28).jpg
# ./data\positive\16 (89).jpg
# ./data\positive\34 (7).jpg
# ./data\positive\16 (73).jpg
# ./data\positive\14 (53).jpg
# ./data\positive\14 (33).jpg
# ./data\positive\14 (24).jpg
# ./data\positive\14 (49).jpg
# ./data\positive\16 (56).jpg
# ./data\positive\29 (5).jpg
# ./data\negative\55 (3).jpg
# ./data\positive\29 (21).jpg
# ./data\negative\7 (45).jpg
# ./data\positive\26 (1).jpg
# ./data\negative\39 (7).jpg
# ./data\negative\48 (22).jpg
# ./data\positive\10 (40).jpg
# ./data\positive\20 (37).jpg
# ./data\positive\21 (22).jpg
# ./data\positive\18 (35).jpg
# ./data\negative\42 (8).jpg
# ./data\positive\5 (20).jpg
# ./data\positive\16 (12).jpg
# ./data\positive\28 (10).jpg
# ./data\positive\10 (28).jpg
# ./data\positive\26 (15).jpg
# ./data\negative\35 (4).jpg
# ./data\negative\57 (11).jpg
# ./data\positive\16 (81).jpg
# ./data\negative\39 (9).jpg
# ./data\positive\16 (55).jpg
# ./data\positive\7 (34).jpg
# ./data\positive\11 (14).jpg
# ./data\positive\20 (19).jpg
# ./data\positive\6 (4).jpg
# ./data\negative\48 (8).jpg
# ./data\negative\24 (12).jpg
# ./data\positive\11 (27).jpg
# ./data\positive\17 (10).jpg
# ./data\negative\50 (5).jpg
# ./data\positive\18 (8).jpg
# ./data\negative\39 (3).jpg
# ./data\negative\56 (1).jpg
# ./data\negative\41 (31).jpg
# ./data\positive\13 (2).jpg
# ./data\positive\20 (18).jpg
# ./data\negative\49 (7).jpg
# ./data\positive\13 (41).jpg
# ./data\positive\33 (3).jpg
# ./data\positive\5 (13).jpg
# ./data\positive\1 (22).jpg
# ./data\positive\11 (18).jpg
# ./data\positive\3 (4).jpg
# ./data\negative\40 (1).jpg
# ./data\negative\41 (4).jpg
# ./data\negative\14 (5).jpg
# ./data\positive\13 (23).jpg
# ./data\positive\16 (66).jpg
# ./data\positive\3 (8).jpg
# ./data\negative\48 (24).jpg
# ./data\positive\14 (41).jpg
# ./data\positive\28 (2).jpg
# ./data\positive\13 (14).jpg
# ./data\positive\8 (21).jpg
# ./data\negative\47 (6).jpg
# ./data\positive\14 (2).jpg
# ./data\negative\26 (19).jpg
# ./data\positive\13 (25).jpg
# ./data\positive\20 (28).jpg
# ./data\positive\7 (24).jpg
# ./data\negative\50 (1).jpg
# ./data\negative\18 (25).jpg
# ./data\positive\15 (1).jpg
# ./data\negative\10 (15).jpg
# ./data\positive\2 (23).jpg
# ./data\positive\14 (51).jpg
# ./data\positive\6 (15).jpg
# ./data\negative\14 (13).jpg
# ./data\negative\36 (20).jpg
# ./data\negative\41 (8).jpg
# ./data\negative\52 (1).jpg
# ./data\negative\50 (8).jpg
# ./data\negative\39 (12).jpg
# ./data\positive\16 (50).jpg
# ./data\positive\3 (19).jpg
# ./data\positive\26 (18).jpg
# ./data\positive\1 (16).jpg
# ./data\negative\36 (7).jpg
# ./data\positive\20 (30).jpg
# ./data\negative\51 (5).jpg
# ./data\negative\41 (17).jpg
# ./data\negative\58 (5).jpg
# ./data\positive\8 (11).jpg
# ./data\positive\9 (7).jpg
# ./data\negative\39 (11).jpg
# ./data\negative\1 (23).jpg
# ./data\positive\30 (18).jpg
# ./data\positive\12 (3).jpg
# ./data\positive\21 (20).jpg
# ./data\positive\9 (18).jpg
# ./data\positive\20 (2).jpg
# ./data\positive\29 (35).jpg
# ./data\positive\31 (1).jpg
# ./data\positive\31 (3).jpg
# ./data\negative\46 (5).jpg
# ./data\positive\1 (6).jpg
# ./data\positive\5 (10).jpg
# ./data\positive\16 (96).jpg
# ./data\negative\48 (13).jpg
# ./data\negative\18 (22).jpg
# ./data\negative\54 (10).jpg
# ./data\negative\37 (2).jpg
# ./data\positive\22 (13).jpg
# ./data\negative\48 (1).jpg
# ./data\negative\48 (23).jpg
# ./data\positive\18 (1).jpg
# ./data\negative\35 (6).jpg
# ./data\positive\21 (17).jpg
# ./data\positive\27 (8).jpg
# ./data\negative\36 (10).jpg
# ./data\positive\5 (14).jpg
# ./data\positive\13 (29).jpg
# ./data\negative\4 (10).jpg
# ./data\negative\42 (9).jpg
# ./data\positive\15 (6).jpg
# ./data\negative\5 (25).jpg
# ./data\positive\6 (1).jpg
# ./data\positive\21 (19).jpg
# ./data\positive\12 (2).jpg
# ./data\negative\53 (8).jpg
# ./data\negative\57 (6).jpg
# ./data\positive\18 (27).jpg
# ./data\negative\45 (4).jpg
# ./data\positive\16 (28).jpg
# ./data\positive\19 (2).jpg
# ./data\positive\16 (2).jpg
# ./data\positive\20 (15).jpg
# ./data\positive\13 (33).jpg
# ./data\negative\8 (22).jpg
# ./data\positive\22 (5).jpg
# ./data\positive\17 (4).jpg
# ./data\negative\56 (5).jpg
# ./data\negative\41 (10).jpg
# ./data\positive\9 (21).jpg
# ./data\negative\57 (9).jpg
# ./data\positive\14 (4).jpg
# ./data\positive\16 (5).jpg
# ./data\negative\41 (3).jpg
# ./data\positive\26 (2).jpg
# ./data\negative\15 (10).jpg
# ./data\negative\49 (10).jpg
# ./data\negative\40 (5).jpg
# ./data\positive\16 (61).jpg
# ./data\positive\25 (6).jpg
# ./data\positive\7 (19).jpg
# ./data\negative\56 (2).jpg
# ./data\negative\52 (2).jpg
# ./data\negative\30 (13).jpg
# ./data\positive\28 (9).jpg
# ./data\negative\49 (17).jpg
# ./data\negative\4 (8).jpg
# ./data\negative\15 (9).jpg
# ./data\positive\31 (11).jpg
# ./data\positive\11 (20).jpg
# ./data\negative\57 (2).jpg
# ./data\positive\20 (38).jpg
# ./data\negative\46 (7).jpg
# ./data\positive\6 (5).jpg
# ./data\negative\48 (7).jpg
# ./data\positive\16 (17).jpg
# ./data\negative\43 (2).jpg
# ./data\positive\21 (10).jpg
# ./data\positive\25 (3).jpg
# ./data\positive\6 (2).jpg
# ./data\negative\18 (23).jpg
# ./data\positive\16 (22).jpg
# ./data\positive\7 (16).jpg
# ./data\positive\23 (5).jpg
# ./data\positive\16 (6).jpg
# ./data\positive\3 (6).jpg
# ./data\positive\10 (27).jpg
# ./data\positive\15 (3).jpg
# ./data\negative\36 (19).jpg
# ./data\positive\11 (17).jpg
# ./data\negative\49 (9).jpg
# ./data\positive\16 (33).jpg
# ./data\positive\16 (74).jpg
# ./data\negative\51 (7).jpg
# ./data\positive\32 (15).jpg
# ./data\positive\18 (4).jpg
# ./data\positive\10 (1).jpg
# ./data\negative\53 (7).jpg
# ./data\negative\48 (16).jpg
# ./data\positive\11 (15).jpg
# ./data\negative\51 (3).jpg
# ./data\negative\24 (13).jpg
# ./data\negative\48 (25).jpg
# ./data\positive\18 (40).jpg
# ./data\positive\29 (44).jpg
# ./data\positive\20 (23).jpg
# ./data\negative\29 (46).jpg
# ./data\positive\32 (6).jpg
# ./data\positive\16 (27).jpg
# ./data\positive\14 (26).jpg
# ./data\positive\3 (16).jpg
# ./data\positive\16 (100).jpg
# ./data\positive\20 (26).jpg
# ./data\negative\44 (3).jpg
# ./data\negative\35 (1).jpg
# ./data\negative\36 (4).jpg
# ./data\positive\15 (2).jpg
# ./data\positive\2 (1).jpg
# ./data\positive\4 (15).jpg
# ./data\positive\16 (42).jpg
# ./data\positive\16 (35).jpg
# ./data\positive\14 (35).jpg
# ./data\positive\34 (6).jpg
# ./data\negative\50 (9).jpg
# ./data\negative\35 (10).jpg
# ./data\negative\29 (14).jpg
# ./data\positive\20 (7).jpg
# ./data\positive\25 (4).jpg
# ./data\negative\36 (12).jpg
# ./data\positive\19 (5).jpg
# ./data\positive\16 (104).jpg
# ./data\positive\16 (103).jpg
# ./data\positive\31 (2).jpg
# ./data\negative\58 (6).jpg
# ./data\positive\20 (5).jpg
# ./data\positive\32 (4).jpg
# ./data\positive\16 (40).jpg
# ./data\positive\5 (11).jpg
# ./data\positive\29 (34).jpg
# ./data\positive\30 (5).jpg
# ./data\positive\16 (32).jpg
# ./data\negative\7 (35).jpg
# ./data\positive\10 (18).jpg
# ./data\positive\14 (22).jpg
# ./data\negative\46 (19).jpg
# ./data\positive\29 (31).jpg
# ./data\negative\47 (3).jpg
# ./data\positive\16 (71).jpg
# ./data\positive\17 (8).jpg
# ./data\negative\46 (12).jpg
# ./data\positive\16 (95).jpg
# ./data\negative\51 (4).jpg
# ./data\positive\16 (10).jpg
# ./data\positive\14 (20).jpg
# ./data\negative\47 (5).jpg
# ./data\positive\16 (47).jpg
# ./data\positive\20 (41).jpg
# ./data\negative\13 (20).jpg
# ./data\positive\30 (2).jpg
# ./data\positive\18 (45).jpg
# ./data\negative\47 (4).jpg
# ./data\positive\11 (12).jpg
# ./data\negative\35 (8).jpg
# ./data\positive\24 (8).jpg
# ./data\positive\13 (31).jpg
# ./data\positive\22 (23).jpg
# ./data\negative\37 (3).jpg
# ./data\negative\41 (29).jpg
# ./data\positive\17 (6).jpg
# ./data\positive\3 (15).jpg
# ./data\positive\5 (8).jpg
# ./data\positive\16 (75).jpg
# ./data\positive\20 (43).jpg
# ./data\positive\4 (4).jpg
# ./data\negative\38 (2).jpg
# ./data\negative\29 (8).jpg
# ./data\negative\57 (1).jpg
# ./data\negative\31 (6).jpg
# ./data\positive\11 (16).jpg
# ./data\positive\7 (1).jpg
# ./data\positive\23 (2).jpg
# ./data\negative\57 (17).jpg
# ./data\negative\43 (10).jpg
# ./data\positive\8 (6).jpg
# ./data\negative\57 (18).jpg
# ./data\positive\14 (36).jpg
# ./data\negative\35 (11).jpg
# ./data\positive\6 (17).jpg
# ./data\positive\2 (2).jpg
# ./data\positive\16 (69).jpg
# ./data\negative\54 (13).jpg
# ./data\negative\39 (14).jpg
# ./data\positive\14 (29).jpg
# ./data\positive\16 (34).jpg
# ./data\negative\41 (30).jpg
# ./data\negative\18 (13).jpg
# ./data\negative\46 (22).jpg
# ./data\negative\21 (16).jpg
# ./data\positive\26 (21).jpg
# ./data\positive\16 (82).jpg
# ./data\negative\8 (25).jpg
# ./data\positive\2 (6).jpg
# ./data\positive\1 (17).jpg
# ./data\positive\16 (68).jpg
# ./data\negative\45 (3).jpg
# ./data\positive\20 (42).jpg
# ./data\positive\7 (14).jpg
# ./data\positive\14 (3).jpg
# ./data\negative\48 (2).jpg
# ./data\positive\16 (65).jpg
# ./data\negative\4 (12).jpg
# ./data\negative\44 (5).jpg
# ./data\positive\30 (11).jpg
# ./data\positive\14 (52).jpg
# ./data\negative\7 (2).jpg
# ./data\positive\5 (29).jpg
# ./data\negative\51 (1).jpg
# ./data\negative\36 (1).jpg
# ./data\positive\27 (3).jpg
# ./data\negative\36 (15).jpg
# ./data\positive\29 (42).jpg
# ./data\negative\15 (8).jpg
# ./data\positive\8 (3).jpg
# ./data\positive\26 (6).jpg
# ./data\positive\14 (47).jpg
# ./data\negative\44 (4).jpg
# ./data\positive\19 (3).jpg
# ./data\positive\17 (14).jpg
# ./data\positive\19 (4).jpg
# ./data\positive\29 (23).jpg
# ./data\positive\10 (23).jpg
# ./data\positive\24 (6).jpg
# ./data\positive\16 (9).jpg
# ./data\negative\14 (40).jpg
# ./data\positive\16 (30).jpg
# ./data\negative\39 (5).jpg
# ./data\positive\16 (23).jpg
# ./data\negative\48 (12).jpg
# ./data\negative\40 (2).jpg
# ./data\positive\10 (26).jpg
# ./data\positive\14 (39).jpg
# ./data\negative\14 (11).jpg
# ./data\positive\29 (6).jpg
# ./data\positive\2 (24).jpg
# ./data\negative\49 (4).jpg
# ./data\positive\7 (26).jpg
# ./data\positive\13 (9).jpg
# ./data\positive\26 (10).jpg
# ./data\negative\14 (15).jpg
# ./data\negative\55 (6).jpg
# ./data\positive\13 (1).jpg
# ./data\positive\20 (17).jpg
# ./data\negative\28 (7).jpg
# ./data\negative\5 (26).jpg
# ./data\positive\27 (5).jpg
# ./data\positive\9 (4).jpg
# ./data\positive\10 (21).jpg
# ./data\negative\49 (5).jpg
# ./data\negative\44 (1).jpg
# ./data\positive\16 (80).jpg
# ./data\positive\10 (38).jpg
# ./data\positive\3 (11).jpg
# ./data\positive\34 (1).jpg
# ./data\negative\1 (7).jpg
# ./data\positive\16 (16).jpg
# ./data\positive\20 (40).jpg
# ./data\positive\14 (19).jpg
# ./data\positive\20 (35).jpg
# ./data\positive\14 (45).jpg
# ./data\positive\3 (18).jpg
# ./data\positive\22 (26).jpg
# ./data\positive\20 (8).jpg
# ./data\negative\57 (15).jpg
# ./data\positive\33 (12).jpg
# ./data\negative\50 (7).jpg
# ./data\positive\5 (5).jpg
# ./data\positive\8 (7).jpg
# ./data\positive\18 (29).jpg
# ./data\positive\23 (6).jpg
# ./data\positive\7 (10).jpg
# ./data\negative\43 (8).jpg
# ./data\negative\40 (7).jpg
# ./data\positive\3 (5).jpg
# ./data\positive\20 (20).jpg
# ./data\positive\26 (7).jpg
# ./data\positive\10 (9).jpg
# ./data\negative\47 (7).jpg
# ./data\positive\22 (10).jpg
# ./data\negative\39 (13).jpg
# ./data\negative\18 (7).jpg
# ./data\negative\40 (3).jpg
# ./data\negative\53 (3).jpg
# ./data\positive\30 (3).jpg
# ./data\positive\3 (7).jpg
# ./data\positive\20 (13).jpg
# ./data\positive\16 (60).jpg
# ./data\negative\55 (11).jpg
# ./data\positive\2 (10).jpg
# ./data\positive\5 (4).jpg
# ./data\positive\32 (11).jpg
# ./data\positive\14 (54).jpg
# ./data\positive\26 (4).jpg
# ./data\negative\50 (6).jpg
# ./data\negative\51 (2).jpg
# ./data\negative\41 (32).jpg
# ./data\positive\31 (8).jpg
# ./data\negative\39 (10).jpg
# ./data\negative\36 (8).jpg
# ./data\positive\29 (2).jpg
# ./data\positive\18 (49).jpg
# ./data\negative\57 (19).jpg
# ./data\positive\1 (15).jpg
# ./data\positive\16 (102).jpg
# ./data\negative\52 (5).jpg
# ./data\positive\13 (26).jpg
# ./data\positive\13 (6).jpg
# ./data\positive\16 (63).jpg
# ./data\positive\16 (59).jpg
# ./data\positive\27 (7).jpg
# ./data\positive\5 (33).jpg
# ./data\negative\48 (14).jpg
# ./data\positive\14 (30).jpg
# ./data\negative\46 (9).jpg
# ./data\negative\19 (12).jpg
# ./data\positive\15 (16).jpg
# ./data\positive\16 (88).jpg
# ./data\negative\10 (6).jpg
# ./data\positive\29 (32).jpg
# ./data\positive\16 (14).jpg
# ./data\positive\14 (27).jpg
# ./data\positive\25 (11).jpg
# ./data\negative\47 (8).jpg
# ./data\positive\14 (46).jpg
# ./data\positive\5 (7).jpg
# ./data\negative\39 (2).jpg
# ./data\negative\54 (2).jpg
# ./data\positive\30 (7).jpg
# ./data\positive\5 (21).jpg
# ./data\negative\48 (11).jpg
# ./data\positive\25 (5).jpg
# ./data\positive\9 (24).jpg
# ./data\positive\29 (25).jpg
# ./data\negative\51 (6).jpg
# ./data\positive\16 (72).jpg
# ./data\positive\16 (94).jpg
# ./data\positive\20 (10).jpg
# ./data\negative\24 (14).jpg
# ./data\positive\14 (31).jpg
# ./data\negative\35 (5).jpg
# ./data\positive\16 (85).jpg
# ./data\negative\57 (27).jpg
# ./data\negative\39 (6).jpg
# ./data\negative\7 (8).jpg
# ./data\negative\1 (25).jpg
# ./data\negative\39 (17).jpg
# ./data\negative\57 (7).jpg
# ./data\negative\9 (9).jpg
# ./data\positive\17 (1).jpg
# ./data\negative\49 (12).jpg
# ./data\positive\32 (10).jpg
# ./data\negative\57 (24).jpg
# ./data\positive\13 (37).jpg
# ./data\positive\9 (17).jpg
# ./data\negative\41 (16).jpg
# ./data\positive\30 (9).jpg
# ./data\positive\27 (2).jpg
# ./data\positive\29 (29).jpg
# ./data\negative\13 (18).jpg
# ./data\positive\18 (31).jpg
# ./data\positive\13 (44).jpg
# ./data\negative\53 (5).jpg
# ./data\positive\16 (91).jpg
# ./data\negative\49 (15).jpg
# ./data\positive\28 (1).jpg
# ./data\positive\16 (4).jpg
# ./data\negative\35 (7).jpg
# ./data\positive\16 (18).jpg
# ./data\positive\17 (9).jpg
# ./data\negative\45 (7).jpg
# ./data\negative\11 (10).jpg
# ./data\negative\19 (14).jpg
# ./data\positive\20 (14).jpg
# ./data\negative\1 (26).jpg
# ./data\positive\16 (3).jpg
# ./data\negative\41 (9).jpg
# ./data\positive\1 (21).jpg
# ./data\positive\6 (7).jpg
# ./data\negative\41 (18).jpg
# ./data\positive\17 (12).jpg
# ./data\positive\34 (8).jpg
# ./data\positive\25 (10).jpg
# ./data\positive\16 (38).jpg
# ./data\positive\5 (1).jpg
# ./data\positive\20 (36).jpg
# ./data\positive\16 (97).jpg
# ./data\positive\10 (29).jpg
# ./data\positive\13 (34).jpg
# ./data\positive\20 (1).jpg
# ./data\positive\5 (16).jpg
# ./data\positive\30 (20).jpg
# ./data\positive\19 (8).jpg
# ./data\positive\21 (21).jpg
# ./data\negative\48 (3).jpg
# ./data\negative\24 (2).jpg
# ./data\positive\16 (13).jpg
# ./data\positive\9 (1).jpg
# ./data\positive\14 (44).jpg
# ./data\positive\5 (18).jpg
# ./data\positive\2 (7).jpg
# ./data\positive\33 (2).jpg
# ./data\positive\22 (12).jpg
# ./data\positive\5 (9).jpg
# ./data\negative\12 (6).jpg
# ./data\positive\22 (15).jpg
# ./data\positive\7 (9).jpg
# ./data\negative\49 (2).jpg
# ./data\negative\12 (5).jpg
# ./data\negative\8 (19).jpg
# ./data\negative\21 (13).jpg
# ./data\positive\20 (16).jpg
# ./data\positive\2 (13).jpg
# ./data\positive\10 (17).jpg
# ./data\negative\41 (26).jpg
# ./data\positive\4 (5).jpg
# ./data\positive\16 (15).jpg
# ./data\negative\46 (18).jpg
# ./data\positive\16 (49).jpg
# ./data\negative\18 (5).jpg
# ./data\negative\58 (2).jpg
# ./data\negative\48 (9).jpg
# ./data\negative\44 (6).jpg
# ./data\positive\2 (22).jpg
# ./data\negative\57 (16).jpg
# ./data\positive\13 (5).jpg
# ./data\negative\43 (5).jpg
# ./data\positive\15 (11).jpg
# ./data\negative\35 (3).jpg
# ./data\positive\17 (16).jpg
# ./data\positive\20 (33).jpg
# ./data\negative\54 (6).jpg
# ./data\positive\17 (11).jpg
# ./data\negative\21 (15).jpg
# ./data\positive\11 (25).jpg
# ./data\negative\48 (19).jpg
# ./data\positive\4 (14).jpg
# ./data\negative\49 (14).jpg
# ./data\negative\46 (20).jpg
# ./data\negative\55 (9).jpg
# ./data\positive\2 (18).jpg
# ./data\positive\22 (8).jpg
# ./data\positive\16 (7).jpg
# ./data\positive\26 (12).jpg
# ./data\positive\34 (5).jpg
# ./data\positive\26 (9).jpg
# ./data\negative\10 (14).jpg
# ./data\negative\57 (26).jpg
# ./data\positive\13 (38).jpg
# ./data\negative\36 (18).jpg
# ./data\positive\32 (12).jpg
# ./data\positive\29 (17).jpg
# ./data\negative\48 (10).jpg
# ./data\negative\41 (12).jpg
# ./data\negative\48 (18).jpg
# ./data\positive\13 (24).jpg
# ./data\positive\2 (9).jpg
# ./data\negative\46 (17).jpg
# ./data\positive\18 (32).jpg
# ./data\negative\43 (3).jpg
# ./data\negative\5 (22).jpg
# ./data\positive\22 (2).jpg
# ./data\negative\58 (3).jpg
# ./data\negative\46 (10).jpg
# ./data\negative\41 (13).jpg
# ./data\positive\14 (37).jpg
# ./data\positive\15 (5).jpg
# ./data\positive\2 (19).jpg
# ./data\negative\57 (14).jpg
# ./data\negative\56 (6).jpg
# ./data\negative\49 (16).jpg
# ./data\positive\14 (58).jpg
# ./data\negative\36 (5).jpg
# ./data\positive\10 (20).jpg
# ./data\positive\13 (45).jpg
# ./data\negative\41 (15).jpg
# ./data\positive\23 (1).jpg
# ./data\positive\3 (10).jpg
# ./data\negative\8 (5).jpg
# ./data\positive\16 (19).jpg
# ./data\negative\35 (13).jpg
# ./data\positive\29 (39).jpg
# ./data\positive\10 (30).jpg
# ./data\positive\2 (20).jpg
# ./data\negative\49 (13).jpg
# ./data\negative\54 (1).jpg
# ./data\positive\14 (32).jpg
# ./data\positive\19 (7).jpg
# ./data\negative\54 (14).jpg
# ./data\positive\1 (18).jpg
# ./data\positive\14 (17).jpg
# ./data\positive\16 (78).jpg
# ./data\negative\54 (9).jpg
# ./data\negative\57 (28).jpg
# ./data\positive\29 (36).jpg
# ./data\positive\13 (27).jpg
# ./data\negative\40 (6).jpg
# ./data\positive\32 (5).jpg
# ./data\negative\36 (17).jpg
# ./data\negative\41 (7).jpg
# ./data\positive\16 (24).jpg
# ./data\positive\28 (12).jpg
# ./data\positive\32 (3).jpg
# ./data\positive\13 (22).jpg
# ./data\positive\9 (25).jpg
# ./data\positive\29 (43).jpg
# ./data\positive\2 (4).jpg
# ./data\positive\26 (13).jpg
# ./data\negative\56 (3).jpg
# ./data\positive\16 (76).jpg
# ./data\positive\10 (19).jpg
# ./data\positive\8 (10).jpg
# ./data\positive\17 (7).jpg
# ./data\negative\43 (1).jpg
# ./data\positive\16 (90).jpg
# ./data\negative\13 (17).jpg
# ./data\positive\14 (34).jpg
# ./data\negative\55 (4).jpg
# ./data\positive\5 (23).jpg
# ./data\negative\39 (15).jpg
# ./data\positive\10 (33).jpg
# ./data\positive\20 (24).jpg
# ./data\positive\11 (26).jpg
# ./data\positive\15 (4).jpg
# ./data\positive\18 (24).jpg
# ./data\positive\8 (20).jpg
# ./data\positive\14 (42).jpg
# ./data\positive\16 (48).jpg
# ./data\positive\16 (87).jpg
# ./data\negative\42 (2).jpg
# ./data\negative\56 (4).jpg
# ./data\negative\43 (9).jpg
# ./data\positive\29 (27).jpg
# ./data\positive\25 (1).jpg
# ./data\positive\8 (23).jpg
# ./data\negative\54 (5).jpg
# ./data\positive\16 (93).jpg
# ./data\negative\49 (8).jpg
# ./data\negative\12 (4).jpg
# ./data\positive\11 (19).jpg
# ./data\negative\49 (6).jpg
# ./data\negative\12 (7).jpg
# ./data\positive\32 (14).jpg
# ./data\positive\16 (101).jpg
# ./data\positive\12 (1).jpg
# ./data\positive\13 (42).jpg
# ./data\negative\57 (13).jpg
# ./data\negative\46 (4).jpg
# ./data\positive\7 (11).jpg
# ./data\negative\39 (8).jpg
# ./data\positive\14 (23).jpg
# ./data\positive\20 (27).jpg
# ./data\negative\56 (8).jpg
# ./data\negative\41 (2).jpg
# ./data\positive\29 (38).jpg
# ./data\positive\16 (57).jpg
# ./data\positive\11 (24).jpg
# ./data\negative\18 (12).jpg
# ./data\positive\1 (20).jpg
# ./data\negative\48 (21).jpg
# ./data\negative\49 (11).jpg
# ./data\positive\29 (45).jpg
# ./data\negative\7 (33).jpg
# ./data\positive\20 (11).jpg
# ./data\positive\26 (14).jpg
# ./data\negative\2 (11).jpg
# ./data\negative\55 (10).jpg
# ./data\positive\16 (51).jpg
# ./data\positive\5 (17).jpg
# ./data\positive\30 (4).jpg
# ./data\positive\32 (2).jpg
# ./data\positive\16 (79).jpg
# ./data\positive\10 (7).jpg
# ./data\positive\26 (16).jpg
# ./data\positive\10 (10).jpg
# ./data\positive\18 (26).jpg
# ./data\positive\14 (38).jpg
# ./data\positive\22 (22).jpg
# ./data\negative\41 (22).jpg
# ./data\negative\19 (9).jpg
# ./data\positive\16 (54).jpg
# ./data\positive\16 (46).jpg
# ./data\negative\36 (9).jpg
# ./data\negative\11 (9).jpg
# ./data\positive\3 (2).jpg
# ./data\positive\6 (16).jpg
# ./data\positive\33 (8).jpg
# ./data\positive\29 (3).jpg
# ./data\positive\32 (13).jpg
# ./data\positive\12 (8).jpg
# ./data\negative\45 (1).jpg
# ./data\positive\14 (10).jpg
# ./data\positive\29 (33).jpg
# ./data\positive\23 (3).jpg
# ./data\positive\18 (44).jpg
# ./data\negative\48 (4).jpg
# ./data\positive\5 (19).jpg
# ./data\positive\16 (67).jpg
# ./data\positive\9 (11).jpg
# ./data\positive\11 (22).jpg
# ./data\positive\10 (34).jpg
# ./data\positive\32 (1).jpg
# ./data\positive\30 (1).jpg
# ./data\positive\30 (19).jpg
# ./data\negative\57 (10).jpg
# ./data\negative\1 (1).jpg
# ./data\positive\8 (1).jpg
# ./data\negative\22 (19).jpg
# ./data\positive\13 (8).jpg
# ./data\positive\29 (7).jpg
# ./data\negative\35 (2).jpg
# ./data\positive\22 (6).jpg
# ./data\positive\8 (18).jpg
# ./data\positive\27 (1).jpg
# ./data\positive\33 (9).jpg
# ./data\positive\6 (3).jpg
# ./data\negative\45 (5).jpg
# ./data\positive\16 (77).jpg
# ./data\negative\36 (21).jpg
# ./data\positive\18 (17).jpg
# ./data\positive\8 (4).jpg
# ./data\positive\16 (36).jpg
# ./data\negative\35 (12).jpg
# ./data\positive\19 (1).jpg
# ./data\negative\42 (3).jpg
# ./data\negative\41 (1).jpg
# ./data\negative\37 (1).jpg
# ./data\positive\16 (70).jpg
# ./data\negative\32 (9).jpg
# ./data\negative\42 (1).jpg
# ./data\positive\6 (10).jpg
# ./data\positive\19 (6).jpg
# ./data\positive\14 (43).jpg
# ./data\positive\2 (15).jpg
# ./data\negative\40 (4).jpg
# ./data\negative\8 (2).jpg
# ./data\positive\13 (30).jpg
# ./data\positive\18 (48).jpg
# ./data\negative\53 (6).jpg
# ./data\positive\19 (10).jpg
# ./data\negative\50 (2).jpg
# ./data\positive\16 (29).jpg
# ./data\positive\5 (3).jpg
# ./data\positive\7 (15).jpg
# ./data\positive\16 (58).jpg
# ./data\positive\15 (14).jpg
# ./data\positive\22 (28).jpg
# ./data\positive\17 (3).jpg
# ./data\negative\46 (6).jpg
# ./data\positive\29 (41).jpg
# ./data\positive\3 (9).jpg
# ./data\positive\7 (12).jpg
# ./data\positive\14 (59).jpg
# ./data\negative\24 (11).jpg
# ./data\negative\58 (1).jpg
# ./data\negative\26 (20).jpg
# ./data\positive\13 (35).jpg
# ./data\positive\17 (5).jpg
# ./data\positive\16 (84).jpg
# ./data\negative\36 (13).jpg
# ./data\negative\47 (2).jpg
# ./data\negative\45 (2).jpg
# ./data\negative\18 (3).jpg
# ./data\positive\11 (29).jpg
# ./data\positive\15 (15).jpg
# ./data\positive\16 (45).jpg
# ./data\positive\13 (40).jpg
# ./data\positive\16 (62).jpg
# ./data\negative\42 (7).jpg
# ./data\positive\16 (11).jpg
# ./data\positive\26 (8).jpg
# ./data\negative\57 (3).jpg
# ./data\positive\5 (12).jpg
# ./data\negative\54 (11).jpg
# ./data\negative\48 (15).jpg
# ./data\positive\3 (3).jpg
# ./data\positive\16 (20).jpg
# ./data\negative\55 (7).jpg
# ./data\positive\3 (17).jpg
# ./data\negative\41 (21).jpg
# ./data\positive\20 (44).jpg
# val
# ./data\positive\9 (19).jpg
# ./data\negative\50 (4).jpg
# ./data\negative\5 (24).jpg
# ./data\positive\10 (25).jpg
# ./data\negative\54 (3).jpg
# ./data\positive\7 (21).jpg
# ./data\negative\47 (1).jpg
# ./data\negative\41 (33).jpg
# ./data\positive\14 (21).jpg
# ./data\positive\8 (26).jpg
# ./data\positive\23 (4).jpg
# ./data\positive\7 (4).jpg
# ./data\positive\16 (98).jpg
# ./data\positive\24 (7).jpg
# ./data\negative\46 (2).jpg
# ./data\negative\10 (13).jpg
# ./data\negative\48 (5).jpg
# ./data\positive\20 (31).jpg
# ./data\positive\25 (9).jpg
# ./data\negative\52 (4).jpg
# ./data\negative\49 (1).jpg
# ./data\positive\10 (16).jpg
# ./data\negative\50 (3).jpg
# ./data\negative\41 (20).jpg
# ./data\negative\55 (5).jpg
# ./data\positive\22 (11).jpg
# ./data\negative\46 (13).jpg
# ./data\negative\7 (3).jpg
# ./data\negative\56 (7).jpg
# ./data\positive\4 (6).jpg
# ./data\negative\53 (2).jpg
# ./data\negative\7 (40).jpg
# ./data\negative\40 (8).jpg
# ./data\positive\21 (9).jpg
# ./data\negative\54 (7).jpg
# ./data\positive\13 (36).jpg
# ./data\negative\39 (16).jpg
# ./data\positive\10 (31).jpg
# ./data\positive\5 (30).jpg
# ./data\positive\6 (8).jpg
# ./data\negative\36 (2).jpg
# ./data\positive\17 (2).jpg
# ./data\positive\7 (20).jpg
# ./data\positive\16 (37).jpg
# ./data\negative\41 (28).jpg
# ./data\positive\22 (18).jpg
# ./data\negative\41 (5).jpg
# ./data\positive\6 (14).jpg
# ./data\positive\20 (6).jpg
# ./data\negative\57 (25).jpg
# ./data\negative\57 (8).jpg
# ./data\positive\16 (39).jpg
# ./data\positive\27 (4).jpg
# ./data\positive\25 (2).jpg
# ./data\negative\58 (4).jpg
# ./data\negative\57 (4).jpg
# ./data\positive\13 (4).jpg
# ./data\positive\31 (9).jpg
# ./data\positive\14 (25).jpg
# ./data\positive\16 (99).jpg
# ./data\positive\7 (29).jpg
# ./data\negative\35 (9).jpg
# ./data\positive\5 (6).jpg
# ./data\negative\45 (6).jpg
# ./data\negative\57 (20).jpg
# ./data\positive\26 (11).jpg
# ./data\positive\3 (1).jpg
# ./data\negative\30 (14).jpg
# ./data\negative\42 (5).jpg
# ./data\positive\13 (46).jpg
# ./data\negative\37 (5).jpg
# ./data\positive\29 (40).jpg
# ./data\negative\10 (5).jpg
# ./data\negative\57 (21).jpg
# ./data\negative\46 (11).jpg
# ./data\negative\41 (27).jpg
# ./data\negative\38 (3).jpg
# ./data\positive\22 (27).jpg
# ./data\negative\57 (22).jpg
# ./data\positive\5 (28).jpg
# ./data\positive\29 (30).jpg
# ./data\negative\44 (2).jpg
# ./data\positive\13 (32).jpg
# ./data\negative\36 (14).jpg
# ./data\positive\3 (14).jpg
# ./data\positive\10 (3).jpg
# ./data\negative\55 (1).jpg
# ./data\negative\37 (4).jpg
# ./data\negative\14 (12).jpg
# ./data\positive\7 (22).jpg
# ./data\positive\13 (43).jpg
# ./data\positive\10 (2).jpg
# ./data\positive\16 (64).jpg
# ./data\positive\13 (7).jpg
# ./data\negative\40 (9).jpg
# ./data\negative\10 (4).jpg
# ./data\positive\22 (25).jpg
# ./data\negative\43 (6).jpg
# ./data\negative\36 (11).jpg
# ./data\positive\2 (5).jpg
# ./data\positive\28 (3).jpg
# ./data\positive\7 (13).jpg
# ./data\negative\54 (12).jpg
# ./data\positive\13 (15).jpg
# ./data\positive\11 (28).jpg
